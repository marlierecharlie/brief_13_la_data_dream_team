# %%
# Import all of the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import matplotlib as mpl
mpl.rcParams['patch.force_edgecolor'] = True
# %matplotlib inline
from haversine import haversine, Unit
from ipywidgets import interact

# %%
# Importation des CSV
customers = pd.read_csv("olist_customers_dataset.csv")
customers.head()
orders = pd.read_csv("olist_orders_dataset.csv")
items = pd.read_csv("olist_order_items_dataset.csv")
payments = pd.read_csv("olist_order_payments_dataset.csv")
reviews = pd.read_csv("olist_order_reviews_dataset.csv")
geolocations = pd.read_csv("olist_geolocation_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
name_translations = pd.read_csv("product_category_name_translation.csv")

# %%
# Merge de tout les tableaux en un grand tableau à 40 colonnes 
data = customers.merge(orders, on = 'customer_id')\
                .merge(items, on = 'order_id')\
                .merge(payments, on = 'order_id')\
                .merge(reviews, on = 'order_id')\
                .merge(products, on = 'product_id')\
                .merge(name_translations, on = 'product_category_name')\
                .merge(sellers, on = 'seller_id')
data
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 115604  ce2172509c4149d65212484eb761bc37  c5da6424f1f5decedef8672a1a0103e1
# 115605  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 115606  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 115607  ab0cf72dfe0538a63a57d6905ccb7b57  8c3c961a52bb5a0ffbce1d4e6d25cd67
# 115608  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
#
#         customer_zip_code_prefix    customer_city customer_state  \
# 0                          14409           franca             SP
# 1                          68030         santarem             PA
# 2                          68030         santarem             PA
# 3                          92480  nova santa rita             RS
# 4                          25931             mage             RJ
# ...                          ...              ...            ...
# 115604                     88350          brusque             SC
# 115605                      9951          diadema             SP
# 115606                      9951          diadema             SP
# 115607                     35930   joao monlevade             MG
# 115608                     12305          jacarei             SP
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 115604  edcf1e1eeb52381be9388c90152be52d    delivered
# 115605  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 115606  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 115607  2c12150c742ae2fa48bc703964c16c5f    delivered
# 115608  9f7ba492c273ffac8f90a623b8eadd3b    delivered
#
#        order_purchase_timestamp    order_approved_at  \
# 0           2017-05-16 15:05:35  2017-05-16 15:22:12
# 1           2017-11-09 00:50:13  2017-11-10 00:47:48
# 2           2017-11-09 00:50:13  2017-11-10 00:47:48
# 3           2017-05-07 20:11:26  2017-05-08 22:22:56
# 4           2018-02-03 19:45:40  2018-02-04 22:29:19
# ...                         ...                  ...
# 115604      2018-08-21 11:29:05  2018-08-21 11:50:47
# 115605      2018-07-23 18:35:14  2018-07-24 10:31:25
# 115606      2018-07-23 18:35:14  2018-07-24 10:31:25
# 115607      2018-07-28 17:55:27  2018-07-29 18:30:31
# 115608      2018-08-23 12:31:37  2018-08-24 03:24:24
#
#        order_delivered_carrier_date  ... product_description_lenght  \
# 0               2017-05-23 10:47:57  ...                     1141.0
# 1               2017-11-22 01:43:37  ...                     1141.0
# 2               2017-11-22 01:43:37  ...                     1141.0
# 3               2017-05-19 20:16:31  ...                     1141.0
# 4               2018-02-19 18:21:47  ...                     1141.0
# ...                             ...  ...                        ...
# 115604          2018-08-21 15:37:00  ...                     1002.0
# 115605          2018-07-24 14:37:00  ...                      660.0
# 115606          2018-07-24 14:37:00  ...                      942.0
# 115607          2018-07-30 14:54:00  ...                      923.0
# 115608          2018-08-24 15:14:00  ...                      654.0
#
#        product_photos_qty  product_weight_g product_length_cm  \
# 0                     1.0            8683.0              54.0
# 1                     1.0            8683.0              54.0
# 2                     1.0            8683.0              54.0
# 3                     1.0            8683.0              54.0
# 4                     1.0            8683.0              54.0
# ...                   ...               ...               ...
# 115604                3.0            1900.0              19.0
# 115605                3.0             500.0              16.0
# 115606                5.0             500.0              21.0
# 115607                5.0            1000.0              25.0
# 115608                3.0             200.0              16.0
#
#        product_height_cm product_width_cm  product_category_name_english  \
# 0                   64.0             31.0               office_furniture
# 1                   64.0             31.0               office_furniture
# 2                   64.0             31.0               office_furniture
# 3                   64.0             31.0               office_furniture
# 4                   64.0             31.0               office_furniture
# ...                  ...              ...                            ...
# 115604              16.0             16.0          arts_and_craftmanship
# 115605               6.0             16.0          arts_and_craftmanship
# 115606               7.0             14.0          arts_and_craftmanship
# 115607              25.0             25.0          arts_and_craftmanship
# 115608               6.0             16.0          arts_and_craftmanship
#
#         seller_zip_code_prefix      seller_city seller_state
# 0                         8577  itaquaquecetuba           SP
# 1                         8577  itaquaquecetuba           SP
# 2                         8577  itaquaquecetuba           SP
# 3                         8577  itaquaquecetuba           SP
# 4                         8577  itaquaquecetuba           SP
# ...                        ...              ...          ...
# 115604                   95910          lajeado           RS
# 115605                   17201              jau           SP
# 115606                   17201              jau           SP
# 115607                   17201              jau           SP
# 115608                   17201              jau           SP
#
# [115609 rows x 40 columns]

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# .info pour savoir si des données sont manquantes et les types de columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    115609 non-null  object
#  1   customer_unique_id             115609 non-null  object
#  2   customer_zip_code_prefix       115609 non-null  int64
#  3   customer_city                  115609 non-null  object
#  4   customer_state                 115609 non-null  object
#  5   order_id                       115609 non-null  object
#  6   order_status                   115609 non-null  object
#  7   order_purchase_timestamp       115609 non-null  object
#  8   order_approved_at              115595 non-null  object
#  9   order_delivered_carrier_date   114414 non-null  object
#  10  order_delivered_customer_date  113209 non-null  object
#  11  order_estimated_delivery_date  115609 non-null  object
#  12  order_item_id                  115609 non-null  int64
#  13  product_id                     115609 non-null  object
#  14  seller_id                      115609 non-null  object
#  15  shipping_limit_date            115609 non-null  object
#  16  price                          115609 non-null  float64
#  17  freight_value                  115609 non-null  float64
#  18  payment_sequential             115609 non-null  int64
#  19  payment_type                   115609 non-null  object
#  20  payment_installments           115609 non-null  int64
#  21  payment_value                  115609 non-null  float64
#  22  review_id                      115609 non-null  object
#  23  review_score                   115609 non-null  int64
#  24  review_comment_title           13801 non-null   object
#  25  review_comment_message         48906 non-null   object
#  26  review_creation_date           115609 non-null  object
#  27  review_answer_timestamp        115609 non-null  object
#  28  product_category_name          115609 non-null  object
#  29  product_name_lenght            115609 non-null  float64
#  30  product_description_lenght     115609 non-null  float64
#  31  product_photos_qty             115609 non-null  float64
#  32  product_weight_g               115608 non-null  float64
#  33  product_length_cm              115608 non-null  float64
#  34  product_height_cm              115608 non-null  float64
#  35  product_width_cm               115608 non-null  float64
#  36  product_category_name_english  115609 non-null  object
#  37  seller_zip_code_prefix         115609 non-null  int64
#  38  seller_city                    115609 non-null  object
#  39  seller_state                   115609 non-null  object
# dtypes: float64(10), int64(6), object(24)
# memory usage: 36.2+ MB

# %% [markdown]
# Conversion des types int en objet pour que cela soit plus facile a traiter et des types objet en datetime pour le temps.

# %%
# Conversion du type int en objet 
for feature in ['customer_zip_code_prefix', 'seller_zip_code_prefix']:
    data[feature] = data[feature].astype('object')

# %%
# Conversion en type datetime pour le temps en objet
for feature in ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 
                'order_delivered_customer_date', 'order_estimated_delivery_date', 'shipping_limit_date',
                'review_creation_date', 'review_answer_timestamp']:
    data[feature] = pd.to_datetime(data[feature], errors = 'raise', utc = False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115609 entries, 0 to 115608
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    115609 non-null  object
#  1   customer_unique_id             115609 non-null  object
#  2   customer_zip_code_prefix       115609 non-null  object
#  3   customer_city                  115609 non-null  object
#  4   customer_state                 115609 non-null  object
#  5   order_id                       115609 non-null  object
#  6   order_status                   115609 non-null  object
#  7   order_purchase_timestamp       115609 non-null  datetime64[ns]
#  8   order_approved_at              115595 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   114414 non-null  datetime64[ns]
#  10  order_delivered_customer_date  113209 non-null  datetime64[ns]
#  11  order_estimated_delivery_date  115609 non-null  datetime64[ns]
#  12  order_item_id                  115609 non-null  int64
#  13  product_id                     115609 non-null  object
#  14  seller_id                      115609 non-null  object
#  15  shipping_limit_date            115609 non-null  datetime64[ns]
#  16  price                          115609 non-null  float64
#  17  freight_value                  115609 non-null  float64
#  18  payment_sequential             115609 non-null  int64
#  19  payment_type                   115609 non-null  object
#  20  payment_installments           115609 non-null  int64
#  21  payment_value                  115609 non-null  float64
#  22  review_id                      115609 non-null  object
#  23  review_score                   115609 non-null  int64
#  24  review_comment_title           13801 non-null   object
#  25  review_comment_message         48906 non-null   object
#  26  review_creation_date           115609 non-null  datetime64[ns]
#  27  review_answer_timestamp        115609 non-null  datetime64[ns]
#  28  product_category_name          115609 non-null  object
#  29  product_name_lenght            115609 non-null  float64
#  30  product_description_lenght     115609 non-null  float64
#  31  product_photos_qty             115609 non-null  float64
#  32  product_weight_g               115608 non-null  float64
#  33  product_length_cm              115608 non-null  float64
#  34  product_height_cm              115608 non-null  float64
#  35  product_width_cm               115608 non-null  float64
#  36  product_category_name_english  115609 non-null  object
#  37  seller_zip_code_prefix         115609 non-null  object
#  38  seller_city                    115609 non-null  object
#  39  seller_state                   115609 non-null  object
# dtypes: datetime64[ns](8), float64(10), int64(4), object(18)
# memory usage: 36.2+ MB

# %% [markdown]
# .isnull pour les valeurs manquantes et .sum pour toutes les groupées.

# %%
data.isnull().sum()
# Out:
# customer_id                           0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_id                              0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1195
# order_delivered_customer_date      2400
# order_estimated_delivery_date         0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# review_id                             0
# review_score                          0
# review_comment_title             101808
# review_comment_message            66703
# review_creation_date                  0
# review_answer_timestamp               0
# product_category_name                 0
# product_name_lenght                   0
# product_description_lenght            0
# product_photos_qty                    0
# product_weight_g                      1
# product_length_cm                     1
# product_height_cm                     1
# product_width_cm                      1
# product_category_name_english         0
# seller_zip_code_prefix                0
# seller_city                           0
# seller_state                          0
# dtype: int64

# %% [markdown]
# On enlève les colonnes 'review_comment_title' et 'review_comment_message' avec les valeurs manquantes et jugé inutile.

# %%
# Remove des donnée null
data.drop(['review_comment_title', 'review_comment_message'], axis = 1, inplace = True)
data.dropna(axis = 0, inplace = True)

# %%
data.isnull().sum()
# Out:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_creation_date             0
# review_answer_timestamp          0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# product_category_name_english    0
# seller_zip_code_prefix           0
# seller_city                      0
# seller_state                     0
# dtype: int64

# %%
# Etat de ordre
Order_status = data['order_status'].unique().tolist()
Order_status
# Out:
# ['delivered', 'canceled']

# %% [markdown]
# La suite nous permet de voir les informations pour la livraison. Comme exemple 'min = -189 jours' une livraison arrivé 6 mois après l'estimation.

# %%
(data['order_estimated_delivery_date'] - data['order_delivered_customer_date']).describe()
# Out:
# count                        113193
# mean     11 days 09:27:35.216532824
# std      10 days 02:13:47.261634898
# min             -189 days +00:35:53
# 25%                 6 days 13:09:53
# 50%                12 days 01:38:16
# 75%                16 days 07:42:38
# max               146 days 00:23:13
# dtype: object

# %%
# Temps de livraison moyen entre estimation et réel
((data['order_estimated_delivery_date'] - data['order_delivered_customer_date']) / (np.timedelta64(1, 'D'))).plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113193 entries, 0 to 115608
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    113193 non-null  object
#  1   customer_unique_id             113193 non-null  object
#  2   customer_zip_code_prefix       113193 non-null  object
#  3   customer_city                  113193 non-null  object
#  4   customer_state                 113193 non-null  object
#  5   order_id                       113193 non-null  object
#  6   order_status                   113193 non-null  object
#  7   order_purchase_timestamp       113193 non-null  datetime64[ns]
#  8   order_approved_at              113193 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   113193 non-null  datetime64[ns]
#  10  order_delivered_customer_date  113193 non-null  datetime64[ns]
#  11  order_estimated_delivery_date  113193 non-null  datetime64[ns]
#  12  order_item_id                  113193 non-null  int64
#  13  product_id                     113193 non-null  object
#  14  seller_id                      113193 non-null  object
#  15  shipping_limit_date            113193 non-null  datetime64[ns]
#  16  price                          113193 non-null  float64
#  17  freight_value                  113193 non-null  float64
#  18  payment_sequential             113193 non-null  int64
#  19  payment_type                   113193 non-null  object
#  20  payment_installments           113193 non-null  int64
#  21  payment_value                  113193 non-null  float64
#  22  review_id                      113193 non-null  object
#  23  review_score                   113193 non-null  int64
#  24  review_creation_date           113193 non-null  datetime64[ns]
#  25  review_answer_timestamp        113193 non-null  datetime64[ns]
#  26  product_category_name          113193 non-null  object
#  27  product_name_lenght            113193 non-null  float64
#  28  product_description_lenght     113193 non-null  float64
#  29  product_photos_qty             113193 non-null  float64
#  30  product_weight_g               113193 non-null  float64
#  31  product_length_cm              113193 non-null  float64
#  32  product_height_cm              113193 non-null  float64
#  33  product_width_cm               113193 non-null  float64
#  34  product_category_name_english  113193 non-null  object
#  35  seller_zip_code_prefix         113193 non-null  object
#  36  seller_city                    113193 non-null  object
#  37  seller_state                   113193 non-null  object
# dtypes: datetime64[ns](8), float64(10), int64(4), object(16)
# memory usage: 33.7+ MB

# %%
#faire une colonne avec temps moyen
data['delivery_accuracy'] = ((data['order_estimated_delivery_date'] - data['order_delivered_customer_date'])/ (np.timedelta64(1, 'D')))

# %%
# Colonne total pour achat+frais de livraison
data['total_value'] = data['price'].add(data['freight_value'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113193 entries, 0 to 115608
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    113193 non-null  object
#  1   customer_unique_id             113193 non-null  object
#  2   customer_zip_code_prefix       113193 non-null  object
#  3   customer_city                  113193 non-null  object
#  4   customer_state                 113193 non-null  object
#  5   order_id                       113193 non-null  object
#  6   order_status                   113193 non-null  object
#  7   order_purchase_timestamp       113193 non-null  datetime64[ns]
#  8   order_approved_at              113193 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   113193 non-null  datetime64[ns]
#  10  order_delivered_customer_date  113193 non-null  datetime64[ns]
#  11  order_estimated_delivery_date  113193 non-null  datetime64[ns]
#  12  order_item_id                  113193 non-null  int64
#  13  product_id                     113193 non-null  object
#  14  seller_id                      113193 non-null  object
#  15  shipping_limit_date            113193 non-null  datetime64[ns]
#  16  price                          113193 non-null  float64
#  17  freight_value                  113193 non-null  float64
#  18  payment_sequential             113193 non-null  int64
#  19  payment_type                   113193 non-null  object
#  20  payment_installments           113193 non-null  int64
#  21  payment_value                  113193 non-null  float64
#  22  review_id                      113193 non-null  object
#  23  review_score                   113193 non-null  int64
#  24  review_creation_date           113193 non-null  datetime64[ns]
#  25  review_answer_timestamp        113193 non-null  datetime64[ns]
#  26  product_category_name          113193 non-null  object
#  27  product_name_lenght            113193 non-null  float64
#  28  product_description_lenght     113193 non-null  float64
#  29  product_photos_qty             113193 non-null  float64
#  30  product_weight_g               113193 non-null  float64
#  31  product_length_cm              113193 non-null  float64
#  32  product_height_cm              113193 non-null  float64
#  33  product_width_cm               113193 non-null  float64
#  34  product_category_name_english  113193 non-null  object
#  35  seller_zip_code_prefix         113193 non-null  object
#  36  seller_city                    113193 non-null  object
#  37  seller_state                   113193 non-null  object
#  38  delivery_accuracy              113193 non-null  float64
#  39  total_value                    113193 non-null  float64
# dtypes: datetime64[ns](8), float64(12), int64(4), object(16)
# memory usage: 35.4+ MB

# %%
G= geolocations.plot.scatter('geolocation_lng', 'geolocation_lat', alpha=0.1)

# %% [markdown]
# un dataframe(df) test pour merger la geolocations dans le df et voir le résultat obtenu.

# %%
test = data.merge(geolocations,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix', how='left')

# %%
test
# Out:
#                                customer_id                customer_unique_id  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# ...                                    ...                               ...
# 17312099  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
# 17312100  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
# 17312101  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
# 17312102  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
# 17312103  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
#
#          customer_zip_code_prefix customer_city customer_state  \
# 0                           14409        franca             SP
# 1                           14409        franca             SP
# 2                           14409        franca             SP
# 3                           14409        franca             SP
# 4                           14409        franca             SP
# ...                           ...           ...            ...
# 17312099                    12305       jacarei             SP
# 17312100                    12305       jacarei             SP
# 17312101                    12305       jacarei             SP
# 17312102                    12305       jacarei             SP
# 17312103                    12305       jacarei             SP
#
#                                   order_id order_status  \
# 0         00e7ee1b050b8499577073aeb2a297a1    delivered
# 1         00e7ee1b050b8499577073aeb2a297a1    delivered
# 2         00e7ee1b050b8499577073aeb2a297a1    delivered
# 3         00e7ee1b050b8499577073aeb2a297a1    delivered
# 4         00e7ee1b050b8499577073aeb2a297a1    delivered
# ...                                    ...          ...
# 17312099  9f7ba492c273ffac8f90a623b8eadd3b    delivered
# 17312100  9f7ba492c273ffac8f90a623b8eadd3b    delivered
# 17312101  9f7ba492c273ffac8f90a623b8eadd3b    delivered
# 17312102  9f7ba492c273ffac8f90a623b8eadd3b    delivered
# 17312103  9f7ba492c273ffac8f90a623b8eadd3b    delivered
#
#          order_purchase_timestamp   order_approved_at  \
# 0             2017-05-16 15:05:35 2017-05-16 15:22:12
# 1             2017-05-16 15:05:35 2017-05-16 15:22:12
# 2             2017-05-16 15:05:35 2017-05-16 15:22:12
# 3             2017-05-16 15:05:35 2017-05-16 15:22:12
# 4             2017-05-16 15:05:35 2017-05-16 15:22:12
# ...                           ...                 ...
# 17312099      2018-08-23 12:31:37 2018-08-24 03:24:24
# 17312100      2018-08-23 12:31:37 2018-08-24 03:24:24
# 17312101      2018-08-23 12:31:37 2018-08-24 03:24:24
# 17312102      2018-08-23 12:31:37 2018-08-24 03:24:24
# 17312103      2018-08-23 12:31:37 2018-08-24 03:24:24
#
#          order_delivered_carrier_date  ... seller_zip_code_prefix  \
# 0                 2017-05-23 10:47:57  ...                   8577
# 1                 2017-05-23 10:47:57  ...                   8577
# 2                 2017-05-23 10:47:57  ...                   8577
# 3                 2017-05-23 10:47:57  ...                   8577
# 4                 2017-05-23 10:47:57  ...                   8577
# ...                               ...  ...                    ...
# 17312099          2018-08-24 15:14:00  ...                  17201
# 17312100          2018-08-24 15:14:00  ...                  17201
# 17312101          2018-08-24 15:14:00  ...                  17201
# 17312102          2018-08-24 15:14:00  ...                  17201
# 17312103          2018-08-24 15:14:00  ...                  17201
#
#               seller_city  seller_state delivery_accuracy total_value  \
# 0         itaquaquecetuba            SP         10.558623      146.87
# 1         itaquaquecetuba            SP         10.558623      146.87
# 2         itaquaquecetuba            SP         10.558623      146.87
# 3         itaquaquecetuba            SP         10.558623      146.87
# 4         itaquaquecetuba            SP         10.558623      146.87
# ...                   ...           ...               ...         ...
# 17312099              jau            SP          5.912095       24.69
# 17312100              jau            SP          5.912095       24.69
# 17312101              jau            SP          5.912095       24.69
# 17312102              jau            SP          5.912095       24.69
# 17312103              jau            SP          5.912095       24.69
#
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                            14409.0       -20.509897       -47.397866
# 1                            14409.0       -20.497396       -47.399241
# 2                            14409.0       -20.510459       -47.399553
# 3                            14409.0       -20.480940       -47.394161
# 4                            14409.0       -20.515413       -47.398194
# ...                              ...              ...              ...
# 17312099                     12305.0       -23.277103       -45.950189
# 17312100                     12305.0       -23.264503       -45.950139
# 17312101                     12305.0       -23.271503       -45.950624
# 17312102                     12305.0       -23.275286       -45.949532
# 17312103                     12305.0       -23.292768       -45.959512
#
#           geolocation_city geolocation_state
# 0                   franca                SP
# 1                   franca                SP
# 2                   franca                SP
# 3                   franca                SP
# 4                   franca                SP
# ...                    ...               ...
# 17312099           jacareí                SP
# 17312100           jacarei                SP
# 17312101           jacarei                SP
# 17312102           jacarei                SP
# 17312103           jacarei                SP
#
# [17312104 rows x 45 columns]

# %% [markdown]
# Tri de geolacation car trop de zip_code doublons.

# %%
G = geolocations

# %%
G.drop_duplicates(subset=['geolocation_zip_code_prefix'],inplace=True)

# %%
  G
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                              1037       -23.545621       -46.639292
# 1                              1046       -23.546081       -46.644820
# 3                              1041       -23.544392       -46.639499
# 4                              1035       -23.541578       -46.641607
# 5                              1012       -23.547762       -46.635361
# ...                             ...              ...              ...
# 999774                        99955       -28.107588       -52.144019
# 999780                        99970       -28.345143       -51.876926
# 999786                        99910       -27.863500       -52.084760
# 999803                        99920       -27.858716       -52.300403
# 999846                        99952       -28.160371       -51.936922
#
#             geolocation_city geolocation_state
# 0                  sao paulo                SP
# 1                  sao paulo                SP
# 3                  sao paulo                SP
# 4                  sao paulo                SP
# 5                  são paulo                SP
# ...                      ...               ...
# 999774          vila langaro                RS
# 999780               ciriaco                RS
# 999786      floriano peixoto                RS
# 999803              erebango                RS
# 999846  santa cecilia do sul                RS
#
# [19015 rows x 5 columns]

# %% [markdown]
# Cette fois ci tout est bon

# %%
test = data.merge(G,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix', how='left')

# %%
test
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 113188  ce2172509c4149d65212484eb761bc37  c5da6424f1f5decedef8672a1a0103e1
# 113189  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 113190  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 113191  ab0cf72dfe0538a63a57d6905ccb7b57  8c3c961a52bb5a0ffbce1d4e6d25cd67
# 113192  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
#
#        customer_zip_code_prefix    customer_city customer_state  \
# 0                         14409           franca             SP
# 1                         68030         santarem             PA
# 2                         68030         santarem             PA
# 3                         92480  nova santa rita             RS
# 4                         25931             mage             RJ
# ...                         ...              ...            ...
# 113188                    88350          brusque             SC
# 113189                     9951          diadema             SP
# 113190                     9951          diadema             SP
# 113191                    35930   joao monlevade             MG
# 113192                    12305          jacarei             SP
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 113188  edcf1e1eeb52381be9388c90152be52d    delivered
# 113189  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 113190  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 113191  2c12150c742ae2fa48bc703964c16c5f    delivered
# 113192  9f7ba492c273ffac8f90a623b8eadd3b    delivered
#
#        order_purchase_timestamp   order_approved_at  \
# 0           2017-05-16 15:05:35 2017-05-16 15:22:12
# 1           2017-11-09 00:50:13 2017-11-10 00:47:48
# 2           2017-11-09 00:50:13 2017-11-10 00:47:48
# 3           2017-05-07 20:11:26 2017-05-08 22:22:56
# 4           2018-02-03 19:45:40 2018-02-04 22:29:19
# ...                         ...                 ...
# 113188      2018-08-21 11:29:05 2018-08-21 11:50:47
# 113189      2018-07-23 18:35:14 2018-07-24 10:31:25
# 113190      2018-07-23 18:35:14 2018-07-24 10:31:25
# 113191      2018-07-28 17:55:27 2018-07-29 18:30:31
# 113192      2018-08-23 12:31:37 2018-08-24 03:24:24
#
#        order_delivered_carrier_date  ... seller_zip_code_prefix  \
# 0               2017-05-23 10:47:57  ...                   8577
# 1               2017-11-22 01:43:37  ...                   8577
# 2               2017-11-22 01:43:37  ...                   8577
# 3               2017-05-19 20:16:31  ...                   8577
# 4               2018-02-19 18:21:47  ...                   8577
# ...                             ...  ...                    ...
# 113188          2018-08-21 15:37:00  ...                  95910
# 113189          2018-07-24 14:37:00  ...                  17201
# 113190          2018-07-24 14:37:00  ...                  17201
# 113191          2018-07-30 14:54:00  ...                  17201
# 113192          2018-08-24 15:14:00  ...                  17201
#
#             seller_city  seller_state delivery_accuracy total_value  \
# 0       itaquaquecetuba            SP         10.558623      146.87
# 1       itaquaquecetuba            SP         20.993171      137.89
# 2       itaquaquecetuba            SP         20.993171      137.89
# 3       itaquaquecetuba            SP         16.587454      140.61
# 4       itaquaquecetuba            SP         21.118750      137.58
# ...                 ...           ...               ...         ...
# 113188          lajeado            RS         12.453877      314.32
# 113189              jau            SP          9.413773       31.86
# 113190              jau            SP          9.413773       52.77
# 113191              jau            SP         12.259190       77.50
# 113192              jau            SP          5.912095       24.69
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          14409.0       -20.509897       -47.397866
# 1                          68030.0        -2.442747       -54.728950
# 2                          68030.0        -2.442747       -54.728950
# 3                          92480.0       -29.856534       -51.268958
# 4                          25931.0       -22.627556       -43.159942
# ...                            ...              ...              ...
# 113188                     88350.0       -27.121007       -48.941164
# 113189                      9951.0       -23.690071       -46.599952
# 113190                      9951.0       -23.690071       -46.599952
# 113191                     35930.0       -19.801332       -43.177222
# 113192                     12305.0       -23.273735       -45.951049
#
#         geolocation_city geolocation_state
# 0                 franca                SP
# 1               santarém                PA
# 2               santarém                PA
# 3        nova santa rita                RS
# 4                   magé                RJ
# ...                  ...               ...
# 113188           brusque                SC
# 113189           diadema                SP
# 113190           diadema                SP
# 113191    joao monlevade                MG
# 113192           jacarei                SP
#
# [113193 rows x 45 columns]

# %% [markdown]
# Maintenant il faut faire la même chose pour le dataframe principale.

# %%
data
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 115604  ce2172509c4149d65212484eb761bc37  c5da6424f1f5decedef8672a1a0103e1
# 115605  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 115606  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 115607  ab0cf72dfe0538a63a57d6905ccb7b57  8c3c961a52bb5a0ffbce1d4e6d25cd67
# 115608  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
#
#        customer_zip_code_prefix    customer_city customer_state  \
# 0                         14409           franca             SP
# 1                         68030         santarem             PA
# 2                         68030         santarem             PA
# 3                         92480  nova santa rita             RS
# 4                         25931             mage             RJ
# ...                         ...              ...            ...
# 115604                    88350          brusque             SC
# 115605                     9951          diadema             SP
# 115606                     9951          diadema             SP
# 115607                    35930   joao monlevade             MG
# 115608                    12305          jacarei             SP
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 115604  edcf1e1eeb52381be9388c90152be52d    delivered
# 115605  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 115606  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 115607  2c12150c742ae2fa48bc703964c16c5f    delivered
# 115608  9f7ba492c273ffac8f90a623b8eadd3b    delivered
#
#        order_purchase_timestamp   order_approved_at  \
# 0           2017-05-16 15:05:35 2017-05-16 15:22:12
# 1           2017-11-09 00:50:13 2017-11-10 00:47:48
# 2           2017-11-09 00:50:13 2017-11-10 00:47:48
# 3           2017-05-07 20:11:26 2017-05-08 22:22:56
# 4           2018-02-03 19:45:40 2018-02-04 22:29:19
# ...                         ...                 ...
# 115604      2018-08-21 11:29:05 2018-08-21 11:50:47
# 115605      2018-07-23 18:35:14 2018-07-24 10:31:25
# 115606      2018-07-23 18:35:14 2018-07-24 10:31:25
# 115607      2018-07-28 17:55:27 2018-07-29 18:30:31
# 115608      2018-08-23 12:31:37 2018-08-24 03:24:24
#
#        order_delivered_carrier_date  ... product_weight_g product_length_cm  \
# 0               2017-05-23 10:47:57  ...           8683.0              54.0
# 1               2017-11-22 01:43:37  ...           8683.0              54.0
# 2               2017-11-22 01:43:37  ...           8683.0              54.0
# 3               2017-05-19 20:16:31  ...           8683.0              54.0
# 4               2018-02-19 18:21:47  ...           8683.0              54.0
# ...                             ...  ...              ...               ...
# 115604          2018-08-21 15:37:00  ...           1900.0              19.0
# 115605          2018-07-24 14:37:00  ...            500.0              16.0
# 115606          2018-07-24 14:37:00  ...            500.0              21.0
# 115607          2018-07-30 14:54:00  ...           1000.0              25.0
# 115608          2018-08-24 15:14:00  ...            200.0              16.0
#
#         product_height_cm product_width_cm product_category_name_english  \
# 0                    64.0             31.0              office_furniture
# 1                    64.0             31.0              office_furniture
# 2                    64.0             31.0              office_furniture
# 3                    64.0             31.0              office_furniture
# 4                    64.0             31.0              office_furniture
# ...                   ...              ...                           ...
# 115604               16.0             16.0         arts_and_craftmanship
# 115605                6.0             16.0         arts_and_craftmanship
# 115606                7.0             14.0         arts_and_craftmanship
# 115607               25.0             25.0         arts_and_craftmanship
# 115608                6.0             16.0         arts_and_craftmanship
#
#        seller_zip_code_prefix      seller_city  seller_state  \
# 0                        8577  itaquaquecetuba            SP
# 1                        8577  itaquaquecetuba            SP
# 2                        8577  itaquaquecetuba            SP
# 3                        8577  itaquaquecetuba            SP
# 4                        8577  itaquaquecetuba            SP
# ...                       ...              ...           ...
# 115604                  95910          lajeado            RS
# 115605                  17201              jau            SP
# 115606                  17201              jau            SP
# 115607                  17201              jau            SP
# 115608                  17201              jau            SP
#
#         delivery_accuracy total_value
# 0               10.558623      146.87
# 1               20.993171      137.89
# 2               20.993171      137.89
# 3               16.587454      140.61
# 4               21.118750      137.58
# ...                   ...         ...
# 115604          12.453877      314.32
# 115605           9.413773       31.86
# 115606           9.413773       52.77
# 115607          12.259190       77.50
# 115608           5.912095       24.69
#
# [113193 rows x 40 columns]

# %%
data = data.merge(G,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix', how='left')
data
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 113188  ce2172509c4149d65212484eb761bc37  c5da6424f1f5decedef8672a1a0103e1
# 113189  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 113190  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 113191  ab0cf72dfe0538a63a57d6905ccb7b57  8c3c961a52bb5a0ffbce1d4e6d25cd67
# 113192  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
#
#        customer_zip_code_prefix    customer_city customer_state  \
# 0                         14409           franca             SP
# 1                         68030         santarem             PA
# 2                         68030         santarem             PA
# 3                         92480  nova santa rita             RS
# 4                         25931             mage             RJ
# ...                         ...              ...            ...
# 113188                    88350          brusque             SC
# 113189                     9951          diadema             SP
# 113190                     9951          diadema             SP
# 113191                    35930   joao monlevade             MG
# 113192                    12305          jacarei             SP
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 113188  edcf1e1eeb52381be9388c90152be52d    delivered
# 113189  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 113190  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 113191  2c12150c742ae2fa48bc703964c16c5f    delivered
# 113192  9f7ba492c273ffac8f90a623b8eadd3b    delivered
#
#        order_purchase_timestamp   order_approved_at  \
# 0           2017-05-16 15:05:35 2017-05-16 15:22:12
# 1           2017-11-09 00:50:13 2017-11-10 00:47:48
# 2           2017-11-09 00:50:13 2017-11-10 00:47:48
# 3           2017-05-07 20:11:26 2017-05-08 22:22:56
# 4           2018-02-03 19:45:40 2018-02-04 22:29:19
# ...                         ...                 ...
# 113188      2018-08-21 11:29:05 2018-08-21 11:50:47
# 113189      2018-07-23 18:35:14 2018-07-24 10:31:25
# 113190      2018-07-23 18:35:14 2018-07-24 10:31:25
# 113191      2018-07-28 17:55:27 2018-07-29 18:30:31
# 113192      2018-08-23 12:31:37 2018-08-24 03:24:24
#
#        order_delivered_carrier_date  ... seller_zip_code_prefix  \
# 0               2017-05-23 10:47:57  ...                   8577
# 1               2017-11-22 01:43:37  ...                   8577
# 2               2017-11-22 01:43:37  ...                   8577
# 3               2017-05-19 20:16:31  ...                   8577
# 4               2018-02-19 18:21:47  ...                   8577
# ...                             ...  ...                    ...
# 113188          2018-08-21 15:37:00  ...                  95910
# 113189          2018-07-24 14:37:00  ...                  17201
# 113190          2018-07-24 14:37:00  ...                  17201
# 113191          2018-07-30 14:54:00  ...                  17201
# 113192          2018-08-24 15:14:00  ...                  17201
#
#             seller_city  seller_state delivery_accuracy total_value  \
# 0       itaquaquecetuba            SP         10.558623      146.87
# 1       itaquaquecetuba            SP         20.993171      137.89
# 2       itaquaquecetuba            SP         20.993171      137.89
# 3       itaquaquecetuba            SP         16.587454      140.61
# 4       itaquaquecetuba            SP         21.118750      137.58
# ...                 ...           ...               ...         ...
# 113188          lajeado            RS         12.453877      314.32
# 113189              jau            SP          9.413773       31.86
# 113190              jau            SP          9.413773       52.77
# 113191              jau            SP         12.259190       77.50
# 113192              jau            SP          5.912095       24.69
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          14409.0       -20.509897       -47.397866
# 1                          68030.0        -2.442747       -54.728950
# 2                          68030.0        -2.442747       -54.728950
# 3                          92480.0       -29.856534       -51.268958
# 4                          25931.0       -22.627556       -43.159942
# ...                            ...              ...              ...
# 113188                     88350.0       -27.121007       -48.941164
# 113189                      9951.0       -23.690071       -46.599952
# 113190                      9951.0       -23.690071       -46.599952
# 113191                     35930.0       -19.801332       -43.177222
# 113192                     12305.0       -23.273735       -45.951049
#
#         geolocation_city geolocation_state
# 0                 franca                SP
# 1               santarém                PA
# 2               santarém                PA
# 3        nova santa rita                RS
# 4                   magé                RJ
# ...                  ...               ...
# 113188           brusque                SC
# 113189           diadema                SP
# 113190           diadema                SP
# 113191    joao monlevade                MG
# 113192           jacarei                SP
#
# [113193 rows x 45 columns]

# %% [markdown]
# # VIZU

# %% [markdown]
# ## Univariée et datacleaning

# %%
# nombre de catégories avec total de items
data['order_item_id'].value_counts().sort_index()
# Out:
# 1     99171
# 2      9895
# 3      2287
# 4       943
# 5       442
# 6       250
# 7        60
# 8        35
# 9        28
# 10       25
# 11       17
# 12       12
# 13        7
# 14        6
# 15        4
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        1
# Name: order_item_id, dtype: int64

# %%
# catégorie par prix total.
data.groupby('order_item_id')['total_value'].mean().plot(kind='bar',figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='order_item_id'>

# %%
data
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 113188  ce2172509c4149d65212484eb761bc37  c5da6424f1f5decedef8672a1a0103e1
# 113189  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 113190  ee1cfdc92e449920e25d3ca4ab4da4f6  8d80e477643ec569b24592ce3d9dfc4c
# 113191  ab0cf72dfe0538a63a57d6905ccb7b57  8c3c961a52bb5a0ffbce1d4e6d25cd67
# 113192  c61336d6c835632048f973d2f2db598d  428f4721a509be8c52de6ec2900ba918
#
#        customer_zip_code_prefix    customer_city customer_state  \
# 0                         14409           franca             SP
# 1                         68030         santarem             PA
# 2                         68030         santarem             PA
# 3                         92480  nova santa rita             RS
# 4                         25931             mage             RJ
# ...                         ...              ...            ...
# 113188                    88350          brusque             SC
# 113189                     9951          diadema             SP
# 113190                     9951          diadema             SP
# 113191                    35930   joao monlevade             MG
# 113192                    12305          jacarei             SP
#
#                                 order_id order_status  \
# 0       00e7ee1b050b8499577073aeb2a297a1    delivered
# 1       c1d2b34febe9cd269e378117d6681172    delivered
# 2       c1d2b34febe9cd269e378117d6681172    delivered
# 3       b1a5d5365d330d10485e0203d54ab9e8    delivered
# 4       2e604b3614664aa66867856dba7e61b7    delivered
# ...                                  ...          ...
# 113188  edcf1e1eeb52381be9388c90152be52d    delivered
# 113189  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 113190  2ef4a11b6e24fdfbb43b92cb5f95edff    delivered
# 113191  2c12150c742ae2fa48bc703964c16c5f    delivered
# 113192  9f7ba492c273ffac8f90a623b8eadd3b    delivered
#
#        order_purchase_timestamp   order_approved_at  \
# 0           2017-05-16 15:05:35 2017-05-16 15:22:12
# 1           2017-11-09 00:50:13 2017-11-10 00:47:48
# 2           2017-11-09 00:50:13 2017-11-10 00:47:48
# 3           2017-05-07 20:11:26 2017-05-08 22:22:56
# 4           2018-02-03 19:45:40 2018-02-04 22:29:19
# ...                         ...                 ...
# 113188      2018-08-21 11:29:05 2018-08-21 11:50:47
# 113189      2018-07-23 18:35:14 2018-07-24 10:31:25
# 113190      2018-07-23 18:35:14 2018-07-24 10:31:25
# 113191      2018-07-28 17:55:27 2018-07-29 18:30:31
# 113192      2018-08-23 12:31:37 2018-08-24 03:24:24
#
#        order_delivered_carrier_date  ... seller_zip_code_prefix  \
# 0               2017-05-23 10:47:57  ...                   8577
# 1               2017-11-22 01:43:37  ...                   8577
# 2               2017-11-22 01:43:37  ...                   8577
# 3               2017-05-19 20:16:31  ...                   8577
# 4               2018-02-19 18:21:47  ...                   8577
# ...                             ...  ...                    ...
# 113188          2018-08-21 15:37:00  ...                  95910
# 113189          2018-07-24 14:37:00  ...                  17201
# 113190          2018-07-24 14:37:00  ...                  17201
# 113191          2018-07-30 14:54:00  ...                  17201
# 113192          2018-08-24 15:14:00  ...                  17201
#
#             seller_city  seller_state delivery_accuracy total_value  \
# 0       itaquaquecetuba            SP         10.558623      146.87
# 1       itaquaquecetuba            SP         20.993171      137.89
# 2       itaquaquecetuba            SP         20.993171      137.89
# 3       itaquaquecetuba            SP         16.587454      140.61
# 4       itaquaquecetuba            SP         21.118750      137.58
# ...                 ...           ...               ...         ...
# 113188          lajeado            RS         12.453877      314.32
# 113189              jau            SP          9.413773       31.86
# 113190              jau            SP          9.413773       52.77
# 113191              jau            SP         12.259190       77.50
# 113192              jau            SP          5.912095       24.69
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          14409.0       -20.509897       -47.397866
# 1                          68030.0        -2.442747       -54.728950
# 2                          68030.0        -2.442747       -54.728950
# 3                          92480.0       -29.856534       -51.268958
# 4                          25931.0       -22.627556       -43.159942
# ...                            ...              ...              ...
# 113188                     88350.0       -27.121007       -48.941164
# 113189                      9951.0       -23.690071       -46.599952
# 113190                      9951.0       -23.690071       -46.599952
# 113191                     35930.0       -19.801332       -43.177222
# 113192                     12305.0       -23.273735       -45.951049
#
#         geolocation_city geolocation_state
# 0                 franca                SP
# 1               santarém                PA
# 2               santarém                PA
# 3        nova santa rita                RS
# 4                   magé                RJ
# ...                  ...               ...
# 113188           brusque                SC
# 113189           diadema                SP
# 113190           diadema                SP
# 113191    joao monlevade                MG
# 113192           jacarei                SP
#
# [113193 rows x 45 columns]

# %%
data[['price','freight_value']]
# Out:
#          price  freight_value
# 0       124.99          21.88
# 1       112.99          24.90
# 2       112.99          24.90
# 3       124.99          15.62
# 4       106.99          30.59
# ...        ...            ...
# 113188  289.49          24.83
# 113189   19.00          12.86
# 113190   39.90          12.87
# 113191   57.90          19.60
# 113192   11.90          12.79
#
# [113193 rows x 2 columns]

# %%
# total ventes
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
sns.distplot(data['total_value'], bins=800 ,kde=False, color='r')
plt.xlim([0, 600])
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# (0.0, 600.0)

# %% [markdown]
# ## Variables d'intérets

# %% [markdown]
# # Création de delai de livraison

# %%
### Get the seller zip code of each order
middle = items[['order_id', 'seller_id']]
middle_2 = middle.merge(sellers[['seller_id', 'seller_zip_code_prefix']], on = "seller_id", how = "outer")
orders = orders.merge(middle_2, on = "order_id", how = "left")

### Get customer zip code of each order
orders = orders.merge(customers[['customer_id', 'customer_zip_code_prefix']],
             on = 'customer_id', how = "left")


## add seller coordinates to the orders
orders = orders.merge(G, 
             left_on = "seller_zip_code_prefix", 
             right_on = "geolocation_zip_code_prefix", 
             how = "left")

## add customer coordinates to the orders
orders = orders.merge(G, 
             left_on = "customer_zip_code_prefix", 
             right_on = "geolocation_zip_code_prefix", 
             how = "left",
             suffixes = ("_seller", "_customer"))

# %%
## Clean orders
## 1--Filter out orders with multipul sellers
# Because each order only has one delivery date

df = orders.groupby(by="order_id").nunique()

mono_orders = pd.Series(df[df['seller_id'] == 1].index)

filtered_orders = orders.merge(mono_orders, how = 'inner')


## 2--drop rows with missing values
#filtered_orders.isna().sum()
filtered_orders = filtered_orders.drop(columns = ["order_approved_at"])

filtered_orders = filtered_orders.dropna()

# %%
## define a function to get distance from coordinates
from math import radians, sin, cos, asin, sqrt
def haversine_distance(lon1, lat1, lon2, lat2):
    """
    Compute distance between two pairs of (lat, lng)
    """
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    return 2 * 6371 * asin(sqrt(a))

## add distance column to dateset
filtered_orders['distance'] = filtered_orders.apply(
    lambda row: haversine_distance(
        row["geolocation_lng_seller"],
        row["geolocation_lat_seller"],
        row["geolocation_lng_customer"],
        row["geolocation_lat_customer"],
    ),
    axis=1,
)

# %%
df_tmp = items[['order_id', 'product_id']].merge(products[['product_id', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'product_weight_g']],
                                        on = "product_id",
                                        how = "outer")

df_tmp.loc[:, "product_size_cm3"] = df_tmp['product_length_cm'] * df_tmp['product_width_cm'] * df_tmp['product_height_cm']

orders_size_weight = df_tmp.groupby("order_id", as_index = False).sum()[['order_id','product_size_cm3', 'product_weight_g']]

filtered_orders = filtered_orders.merge(orders_size_weight,
                    on = 'order_id',
                    how = 'left')

# %%
## Convert time columns
time_columns = ['order_purchase_timestamp',
                 'order_delivered_customer_date',
                 'order_estimated_delivery_date']

for column in time_columns:
    filtered_orders.loc[:, column] = pd.to_datetime(filtered_orders[column])

filtered_orders.loc[:,"wait_time"] = (filtered_orders['order_delivered_customer_date'] - filtered_orders['order_purchase_timestamp']).dt.days

# %%
filtered_orders
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 106573  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 106574  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 106575  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 106576  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 106577  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp order_delivered_carrier_date  \
# 0         delivered      2017-10-02 10:56:33          2017-10-04 19:55:00
# 1         delivered      2018-07-24 20:41:37          2018-07-26 14:31:00
# 2         delivered      2018-08-08 08:38:49          2018-08-08 13:50:00
# 3         delivered      2017-11-18 19:28:06          2017-11-22 13:39:59
# 4         delivered      2018-02-13 21:18:39          2018-02-14 19:46:34
# ...             ...                      ...                          ...
# 106573    delivered      2018-02-06 12:58:58          2018-02-07 23:22:42
# 106574    delivered      2017-08-27 14:46:43          2017-08-28 20:52:26
# 106575    delivered      2018-01-08 21:28:27          2018-01-12 15:35:03
# 106576    delivered      2018-01-08 21:28:27          2018-01-12 15:35:03
# 106577    delivered      2018-03-08 20:57:30          2018-03-09 22:11:59
#
#        order_delivered_customer_date order_estimated_delivery_date  \
# 0                2017-10-10 21:25:13                    2017-10-18
# 1                2018-08-07 15:27:45                    2018-08-13
# 2                2018-08-17 18:06:29                    2018-09-04
# 3                2017-12-02 00:28:42                    2017-12-15
# 4                2018-02-16 18:17:02                    2018-02-26
# ...                              ...                           ...
# 106573           2018-02-28 17:37:56                    2018-03-02
# 106574           2017-09-21 11:24:17                    2017-09-27
# 106575           2018-01-25 23:32:54                    2018-02-15
# 106576           2018-01-25 23:32:54                    2018-02-15
# 106577           2018-03-16 13:08:30                    2018-04-03
#
#                                seller_id  seller_zip_code_prefix  \
# 0       3504c0cb71d7fa48d967e0e4c94d59d9                  9350.0
# 1       289cdb325fb7e7f891c38608bf9e0962                 31570.0
# 2       4869f7a5dfa277a7dca6462dcf3b52b2                 14840.0
# 3       66922902710d126a0e7d26b0e3805106                 31842.0
# 4       2c9e548be18521d1c43cde1c582c6de8                  8752.0
# ...                                  ...                     ...
# 106573  1f9ab4708f3056ede07124aad39a2554                 17602.0
# 106574  d50d79cb34e38265a8649c383dcffd48                  8290.0
# 106575  a1043bafd471dff536d0c462352beb48                 37175.0
# 106576  a1043bafd471dff536d0c462352beb48                 37175.0
# 106577  ececbfcff9804a2d6b40f589df8eef2b                 14407.0
#
#         customer_zip_code_prefix  ...  geolocation_state_seller  \
# 0                           3149  ...                        SP
# 1                          47813  ...                        MG
# 2                          75265  ...                        SP
# 3                          59296  ...                        MG
# 4                           9195  ...                        SP
# ...                          ...  ...                       ...
# 106573                     11722  ...                        SP
# 106574                     45920  ...                        SP
# 106575                     28685  ...                        MG
# 106576                     28685  ...                        MG
# 106577                     83750  ...                        SP
#
#         geolocation_zip_code_prefix_customer  geolocation_lat_customer  \
# 0                                     3149.0                -23.574809
# 1                                    47813.0                -12.169860
# 2                                    75265.0                -16.746337
# 3                                    59296.0                 -5.767733
# 4                                     9195.0                -23.675037
# ...                                      ...                       ...
# 106573                               11722.0                -24.001467
# 106574                               45920.0                -17.891522
# 106575                               28685.0                -22.555985
# 106576                               28685.0                -22.555985
# 106577                               83750.0                -25.775722
#
#        geolocation_lng_customer geolocation_city_customer  \
# 0                    -46.587471                 sao paulo
# 1                    -44.988369                 barreiras
# 2                    -48.514624                vianopolis
# 3                    -35.275467   sao goncalo do amarante
# 4                    -46.524784               santo andre
# ...                         ...                       ...
# 106573               -46.446355              praia grande
# 106574               -39.370942               nova vicosa
# 106575               -42.690761                   japuiba
# 106576               -42.690761                   japuiba
# 106577               -49.723981                      lapa
#
#         geolocation_state_customer     distance  product_size_cm3  \
# 0                               SP    18.063837            1976.0
# 1                               BA   856.292580            4693.0
# 2                               GO   514.130333            9576.0
# 3                               RN  1822.800366            6000.0
# 4                               SP    30.174037           11475.0
# ...                            ...          ...               ...
# 106573                          SP   474.098245           16000.0
# 106574                          BA   968.051192           63360.0
# 106575                          RJ   370.146853           16000.0
# 106576                          RJ   370.146853           16000.0
# 106577                          PR   631.817784            1680.0
#
#        product_weight_g wait_time
# 0                 500.0         8
# 1                 400.0        13
# 2                 420.0         9
# 3                 450.0        13
# 4                 250.0         2
# ...                 ...       ...
# 106573           4950.0        22
# 106574          13300.0        24
# 106575          13100.0        17
# 106576          13100.0        17
# 106577            150.0         7
#
# [106578 rows x 24 columns]

# %%
filtered_orders.describe()
# Out:
#        seller_zip_code_prefix  customer_zip_code_prefix  \
# count           106578.000000             106578.000000
# mean             24452.317270              35107.453658
# std              27624.542174              29866.845926
# min               1001.000000               1003.000000
# 25%               6429.000000              11310.000000
# 50%              13503.000000              24315.000000
# 75%              27972.000000              58840.000000
# max              99730.000000              99980.000000
#
#        geolocation_zip_code_prefix_seller  geolocation_lat_seller  \
# count                       106578.000000           106578.000000
# mean                         24452.317270              -22.799688
# std                          27624.542174                2.716084
# min                           1001.000000              -36.605374
# 25%                           6429.000000              -23.612053
# 50%                          13503.000000              -23.425946
# 75%                          27972.000000              -21.766477
# max                          99730.000000               -2.546079
#
#        geolocation_lng_seller  geolocation_zip_code_prefix_customer  \
# count           106578.000000                         106578.000000
# mean               -47.229684                          35107.453658
# std                  2.343765                          29866.845926
# min                -64.283946                           1003.000000
# 25%                -48.812471                          11310.000000
# 50%                -46.743493                          24315.000000
# 75%                -46.518082                          58840.000000
# max                -34.847856                          99980.000000
#
#        geolocation_lat_customer  geolocation_lng_customer       distance  \
# count             106578.000000             106578.000000  106578.000000
# mean                 -21.229338                -46.207002     597.877717
# std                    5.587930                  4.054689     592.781228
# min                  -36.605374                -72.666706       0.000000
# 25%                  -23.590818                -48.125260     182.260661
# 50%                  -22.929835                -46.633100     432.348581
# 75%                  -20.180875                -43.659629     793.222821
# max                   42.184003                 -8.577855    8736.947618
#
#        product_size_cm3  product_weight_g      wait_time
# count      1.065780e+05     106578.000000  106578.000000
# mean       2.089869e+04       2839.245417      12.097074
# std        4.359780e+04       6704.404425       9.518642
# min        0.000000e+00          0.000000       0.000000
# 25%        3.136000e+03        335.000000       6.000000
# 50%        8.000000e+03        820.000000      10.000000
# 75%        2.199900e+04       2400.000000      15.000000
# max        1.476000e+06     184400.000000     209.000000

# %%
GS= filtered_orders.plot.scatter('geolocation_lng_seller', 'geolocation_lat_seller', alpha=0.1)

# %%
GC= filtered_orders.plot.scatter('geolocation_lng_customer', 'geolocation_lat_customer', alpha=0.1)

# %%
# Let’s have a quick look at the distribution of these features by plotting their histograms
filtered_orders.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %%
data.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %%
filtered_orders.hist('seller_zip_code_prefix',figsize=(12, 10), bins=30, edgecolor="black",)
plt.subplots_adjust(hspace=0.7, wspace=0.4)
plt.xlabel("Nombre d'apparition", fontsize=16)
plt.ylabel("Zip Code", fontsize=16)
# Out:
# Text(0, 0.5, 'Zip Code')

# %% [markdown]
# Dans ce histogramme nous pouvons voir où les vendeurs sont plus présent.

# %%
filtered_orders.hist('customer_zip_code_prefix',figsize=(12, 10), bins=30, edgecolor="black",)
plt.subplots_adjust(hspace=0.7, wspace=0.4)
plt.xlabel("Nombre d'apparition", fontsize=16)
plt.ylabel("Zip Code", fontsize=16)
# Out:
# Text(0, 0.5, 'Zip Code')

# %% [markdown]
# Dans ce histogramme nous pouvons voir où les acheteurs sont plus présent.

# %%
filtered_orders.hist('wait_time',figsize=(12, 10), bins=30, edgecolor="black",)
plt.subplots_adjust(hspace=0.7, wspace=0.4)
plt.xlabel("Temps de livraison", fontsize=16)
plt.ylabel("Colis", fontsize=16)
# Out:
# Text(0, 0.5, 'Colis')

# %%
time = filtered_orders['wait_time']
time.value_counts()
# Out:
# 7      8434
# 8      7455
# 6      7429
# 9      6619
# 5      6339
#        ...
# 82        1
# 166       1
# 131       1
# 102       1
# 142       1
# Name: wait_time, Length: 146, dtype: int64

# %%
fig1, ax1 = plt.subplots()
ax1.boxplot(time,showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250abf44fd0>,
#   <matplotlib.lines.Line2D at 0x250ae1e52e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x250ae1e5670>,
#   <matplotlib.lines.Line2D at 0x250ae1e5880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250abf44d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x250ae1e5b50>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# La plupart des colis sont livrés entre 6 à 15 jours.

# %%
@interact
def plot_hist(
    column= ['product_weight_g','wait_time', 'product_size_cm3',
            'distance']
):
    plt.figure(figsize= (12,8))
    sns.distplot(filtered_orders[column], kde= True)
    plt.title('Histogram of {}'.format(column), fontdict= {'size':15})
# Out:
# interactive(children=(Dropdown(description='column', options=('product_weight_g', 'wait_time', 'product_size_c…

# %% [markdown]
# Product_weight_g : poid des produits en gramme, la plupart entre 50g et 20kg. Produit le plus lourd 180Kg.
#
# Wait_time : Temps entre confirmation et la livraison, allant de 1 jour à 210 jours et en moyenne cela prend entre 5 à 10jours.
#
# Product_size_cm3 : Volume du produit.
#
# Distance : Entre le vendeur et acheteur.

# %%
@interact
def plot_hist(
    column= ['product_weight_g', 'product_length_cm',
            'product_height_cm','product_width_cm', 'freight_value', 'price']
):
    plt.figure(figsize= (12,8))
    sns.distplot(data[column], kde= True)
    plt.title('Histogram of {}'.format(column), fontdict= {'size':15})
# Out:
# interactive(children=(Dropdown(description='column', options=('product_weight_g', 'product_length_cm', 'produc…

# %%
cor = filtered_orders.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor, annot=True, fmt=".2g", linewidths=0.9)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Les features d'entrées à utiliser sont les :
#
# Localisation du Vendeur : Pour le point de départ du colis.
#
# Localisation du acheteur: Pour le point d'arrivée du colis
#
# la distance : La distance à parcourir pour livrer
#
# Le produit : Dans le quel nous avons son poid et sa taille

# %% [markdown]
# # Géo

# %%
import folium
from folium.plugins import HeatMap
from folium.plugins import HeatMapWithTime

# %%
center_location = [-22.9020, -43.1882]
m = folium.Map(location=center_location, control_scale=True, zoom_start=11)

# %%
# %matplotlib notebook
filtered_orders.loc[:, "count"] =1
heatmap_data = filtered_orders.head(10000)[['geolocation_lat_seller', 'geolocation_lng_seller', 'count']].groupby(['geolocation_lat_seller', 'geolocation_lng_seller']).sum().reset_index().values.tolist()
gradient = {0.1: 'blue', 0.2: 'lime', 0.3: 'orange', 0.4: 'red', 0.5: 'purple', 0.6: 'black'}
HeatMap(data=heatmap_data, radius=5, gradient=gradient, max_zoom=13).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93b77003d6b762b6627f26a5811c58f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93b77003d6b762b6627f26a5811c58f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93b77003d6b762b6627f26a5811c58f1 = L.map(
#                 &quot;map_93b77003d6b762b6627f26a5811c58f1&quot;,
#                 {
#                     center: [-22.902, -43.1882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_93b77003d6b762b6627f26a5811c58f1);
#
#
#
#
#
#             var tile_layer_f846bc36d3f87a98cda4b5f76c75b63a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93b77003d6b762b6627f26a5811c58f1);
#
#
#             var heat_map_731f5da96dcc5acfd6eb66d2a6375e5b = L.heatLayer(
#                 [[-32.0795133795473, -52.15767795961282, 1.0], [-30.15946930410813, -50.832839089335735, 6.0], [-30.110020899532547, -51.23162798932419, 3.0], [-30.08061351221984, -51.0272582031978, 1.0], [-30.07200823826747, -51.17719962332037, 3.0], [-30.03215040714993, -51.2325516998384, 14.0], [-30.02445275114225, -51.21118835646234, 2.0], [-30.02360801408486, -52.91332609031451, 1.0], [-30.0222114410237, -51.15161116293486, 1.0], [-30.01895817707312, -51.16296204564608, 5.0], [-30.01769047489746, -51.19121208090485, 1.0], [-30.013169904996133, -51.19853892141162, 2.0], [-30.009630605709347, -51.07718453138239, 1.0], [-30.00731246906908, -51.19422244408211, 23.0], [-29.95355420966261, -51.103414237425575, 6.0], [-29.914668849530724, -51.14844143722624, 14.0], [-29.90828909779852, -51.069163834525725, 1.0], [-29.891348178542295, -50.27310902841568, 3.0], [-29.77065486733257, -51.13215300635966, 1.0], [-29.698897125855755, -52.44208124328146, 2.0], [-29.6960435029035, -51.24351819389478, 2.0], [-29.691002326389324, -53.80623715543304, 1.0], [-29.6881809883103, -51.0915608374261, 11.0], [-29.681001176488756, -51.07531051934418, 1.0], [-29.67923604262464, -51.14794390232424, 1.0], [-29.67034898140752, -51.46146829327502, 14.0], [-29.65510565471189, -50.577744262161566, 1.0], [-29.616140787882497, -52.17587557262544, 1.0], [-29.44175457955597, -51.96130964790591, 6.0], [-29.430489990467024, -52.00653647329336, 1.0], [-29.333594390939208, -49.73818879957859, 1.0], [-29.1962475, -51.180777, 1.0], [-29.193359085518043, -51.162024291842336, 1.0], [-29.184320575640843, -51.23000145931209, 1.0], [-29.178365921096788, -51.17747690331007, 1.0], [-29.17682210847989, -51.15690685509721, 3.0], [-29.16624369279465, -51.209531752064, 5.0], [-29.159003201842477, -51.49977005197258, 5.0], [-29.15817748296765, -51.20612593982097, 6.0], [-29.11321350581612, -49.628523808338834, 1.0], [-29.03399624689176, -51.1917479847557, 1.0], [-28.87262510202068, -52.17938515160991, 2.0], [-28.7629920668113, -49.27499226831797, 9.0], [-28.680422038680614, -49.36995209892042, 1.0], [-28.680001204874007, -49.345926043307074, 1.0], [-28.673779235468725, -49.37314563727728, 3.0], [-28.621531461000867, -49.023995719014565, 5.0], [-28.599674794891307, -51.78893967854048, 2.0], [-28.46951928224586, -48.99324969252177, 5.0], [-28.327530882623098, -49.18050954005345, 7.0], [-28.28944621405989, -52.79412331824494, 3.0], [-28.281003423550747, -54.258283178397335, 6.0], [-28.27354928978744, -49.16896410025293, 2.0], [-28.190231258277556, -48.66460352500113, 1.0], [-27.99110094793968, -54.84605581154811, 1.0], [-27.962987017603908, -48.67050566252546, 1.0], [-27.82214624923539, -50.34177358422306, 5.0], [-27.81568867055225, -50.33589889924407, 13.0], [-27.783656327360223, -52.8078324850087, 1.0], [-27.729372911015968, -52.537491045681705, 1.0], [-27.713180999999945, -54.26528299999997, 3.0], [-27.675399941807463, -48.68445574523188, 1.0], [-27.623801411846078, -48.67428578001718, 1.0], [-27.60731306466045, -48.59058002775691, 11.0], [-27.60066334139297, -48.51412134485542, 1.0], [-27.59598577448037, -48.54618547457063, 4.0], [-27.58917099140166, -48.579840372323886, 2.0], [-27.58902112461769, -48.598946219401, 1.0], [-27.543786658615705, -48.62567962615467, 13.0], [-27.541774322739933, -48.524876521904254, 1.0], [-27.42517433269942, -48.426350651572776, 5.0], [-27.288614821408185, -50.57696646191445, 3.0], [-27.23087744199508, -49.73043032302249, 2.0], [-27.227305885654083, -49.64789177350121, 2.0], [-27.218980466558925, -49.65040322964413, 1.0], [-27.211807695727405, -52.0209908478637, 4.0], [-27.20981137280685, -49.63292048422235, 20.0], [-27.154606768453945, -48.56986624316197, 1.0], [-27.14294161449014, -48.50728684609616, 7.0], [-27.14105704919435, -48.96146112936535, 29.0], [-27.12100682014913, -48.94116396455869, 2.0], [-27.082320621703506, -48.93028666250217, 1.0], [-27.0008687

# %% [markdown]
# HeatMap permet de voir où les vendeurs sont les plus présent.

# %%
# %matplotlib notebook
filtered_orders.loc[:, "count"] =1
heatmap_data = filtered_orders.head(10000)[['geolocation_lat_customer', 'geolocation_lng_customer', 'count']].groupby(['geolocation_lat_customer', 'geolocation_lng_customer']).sum().reset_index().values.tolist()
gradient = {0.1: 'blue', 0.2: 'lime', 0.3: 'orange', 0.4: 'red', 0.5: 'purple', 0.6: 'black'}
HeatMap(data=heatmap_data, radius=5, gradient=gradient, max_zoom=13).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93b77003d6b762b6627f26a5811c58f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93b77003d6b762b6627f26a5811c58f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93b77003d6b762b6627f26a5811c58f1 = L.map(
#                 &quot;map_93b77003d6b762b6627f26a5811c58f1&quot;,
#                 {
#                     center: [-22.902, -43.1882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_93b77003d6b762b6627f26a5811c58f1);
#
#
#
#
#
#             var tile_layer_f846bc36d3f87a98cda4b5f76c75b63a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93b77003d6b762b6627f26a5811c58f1);
#
#
#             var heat_map_731f5da96dcc5acfd6eb66d2a6375e5b = L.heatLayer(
#                 [[-32.0795133795473, -52.15767795961282, 1.0], [-30.15946930410813, -50.832839089335735, 6.0], [-30.110020899532547, -51.23162798932419, 3.0], [-30.08061351221984, -51.0272582031978, 1.0], [-30.07200823826747, -51.17719962332037, 3.0], [-30.03215040714993, -51.2325516998384, 14.0], [-30.02445275114225, -51.21118835646234, 2.0], [-30.02360801408486, -52.91332609031451, 1.0], [-30.0222114410237, -51.15161116293486, 1.0], [-30.01895817707312, -51.16296204564608, 5.0], [-30.01769047489746, -51.19121208090485, 1.0], [-30.013169904996133, -51.19853892141162, 2.0], [-30.009630605709347, -51.07718453138239, 1.0], [-30.00731246906908, -51.19422244408211, 23.0], [-29.95355420966261, -51.103414237425575, 6.0], [-29.914668849530724, -51.14844143722624, 14.0], [-29.90828909779852, -51.069163834525725, 1.0], [-29.891348178542295, -50.27310902841568, 3.0], [-29.77065486733257, -51.13215300635966, 1.0], [-29.698897125855755, -52.44208124328146, 2.0], [-29.6960435029035, -51.24351819389478, 2.0], [-29.691002326389324, -53.80623715543304, 1.0], [-29.6881809883103, -51.0915608374261, 11.0], [-29.681001176488756, -51.07531051934418, 1.0], [-29.67923604262464, -51.14794390232424, 1.0], [-29.67034898140752, -51.46146829327502, 14.0], [-29.65510565471189, -50.577744262161566, 1.0], [-29.616140787882497, -52.17587557262544, 1.0], [-29.44175457955597, -51.96130964790591, 6.0], [-29.430489990467024, -52.00653647329336, 1.0], [-29.333594390939208, -49.73818879957859, 1.0], [-29.1962475, -51.180777, 1.0], [-29.193359085518043, -51.162024291842336, 1.0], [-29.184320575640843, -51.23000145931209, 1.0], [-29.178365921096788, -51.17747690331007, 1.0], [-29.17682210847989, -51.15690685509721, 3.0], [-29.16624369279465, -51.209531752064, 5.0], [-29.159003201842477, -51.49977005197258, 5.0], [-29.15817748296765, -51.20612593982097, 6.0], [-29.11321350581612, -49.628523808338834, 1.0], [-29.03399624689176, -51.1917479847557, 1.0], [-28.87262510202068, -52.17938515160991, 2.0], [-28.7629920668113, -49.27499226831797, 9.0], [-28.680422038680614, -49.36995209892042, 1.0], [-28.680001204874007, -49.345926043307074, 1.0], [-28.673779235468725, -49.37314563727728, 3.0], [-28.621531461000867, -49.023995719014565, 5.0], [-28.599674794891307, -51.78893967854048, 2.0], [-28.46951928224586, -48.99324969252177, 5.0], [-28.327530882623098, -49.18050954005345, 7.0], [-28.28944621405989, -52.79412331824494, 3.0], [-28.281003423550747, -54.258283178397335, 6.0], [-28.27354928978744, -49.16896410025293, 2.0], [-28.190231258277556, -48.66460352500113, 1.0], [-27.99110094793968, -54.84605581154811, 1.0], [-27.962987017603908, -48.67050566252546, 1.0], [-27.82214624923539, -50.34177358422306, 5.0], [-27.81568867055225, -50.33589889924407, 13.0], [-27.783656327360223, -52.8078324850087, 1.0], [-27.729372911015968, -52.537491045681705, 1.0], [-27.713180999999945, -54.26528299999997, 3.0], [-27.675399941807463, -48.68445574523188, 1.0], [-27.623801411846078, -48.67428578001718, 1.0], [-27.60731306466045, -48.59058002775691, 11.0], [-27.60066334139297, -48.51412134485542, 1.0], [-27.59598577448037, -48.54618547457063, 4.0], [-27.58917099140166, -48.579840372323886, 2.0], [-27.58902112461769, -48.598946219401, 1.0], [-27.543786658615705, -48.62567962615467, 13.0], [-27.541774322739933, -48.524876521904254, 1.0], [-27.42517433269942, -48.426350651572776, 5.0], [-27.288614821408185, -50.57696646191445, 3.0], [-27.23087744199508, -49.73043032302249, 2.0], [-27.227305885654083, -49.64789177350121, 2.0], [-27.218980466558925, -49.65040322964413, 1.0], [-27.211807695727405, -52.0209908478637, 4.0], [-27.20981137280685, -49.63292048422235, 20.0], [-27.154606768453945, -48.56986624316197, 1.0], [-27.14294161449014, -48.50728684609616, 7.0], [-27.14105704919435, -48.96146112936535, 29.0], [-27.12100682014913, -48.94116396455869, 2.0], [-27.082320621703506, -48.93028666250217, 1.0], [-27.0008687

# %% [markdown]
# HeatMap permet de voir où les acheteur sont les plus présent.

# %%
def directed_error(y,y_pred):
    '''The difference between estimated delivery time
    and actual delivery time. Positive number (delivered before estimation time) is prefered.'''
    return np.mean(y_pred - y)

y_base = (filtered_orders['order_estimated_delivery_date'] - filtered_orders['order_purchase_timestamp']).dt.days

basic_score = directed_error(filtered_orders['wait_time'], y_base)
basic_score
# Out:
# 11.290435174238587

# %% [markdown]
# ## Milestone 4 : analyse multivariée

# %%
state_grouped = (data.groupby('customer_state')[['price', 'review_score']]
                             .agg({'review_score': ['mean', 'count'], 'price':['mean']})
                ).sort_values(by=('review_score','mean'), ascending=False)
                 
state_grouped.head()
# Out:
#                review_score              price
#                        mean  count        mean
# customer_state
# AP                 4.280488     82  164.742805
# TO                 4.182371    329  165.744043
# SP                 4.180394  47812  109.490344
# PR                 4.145078   5790  117.657131
# MG                 4.121217  13216  119.443892

# %%
state_grouped.plot(kind='barh', figsize=(12,11), logx=True,title='Customer/Price/review')
# Out:
# <img src="data:image/png;base64,..." width="864">
# <AxesSubplot:title={'center':'Customer/Price/review'}, ylabel='customer_state'>

# %%
fig, (ax1,ax2) = plt.subplots(2,1)
fig.set_figheight(8)
fig.set_figwidth(15)

(data.groupby(data['order_purchase_timestamp'].dt.month)['price'].mean()
      .plot(kind='bar', ax=ax1, ylim=(0,140), 
            title='Average Prices for Orders in Brazilian Real Per Month')
)
(data.groupby(data['order_purchase_timestamp'].dt.month)['price'].sum()
      .plot(kind='bar', ax=ax2, ylim=(600000,1350000), sharex=True,
           title='Total Volume of Orders in Brazilian Reals Per Month')
)
# Out:
# <img src="data:image/png;base64,..." width="1080">
# <AxesSubplot:title={'center':'Total Volume of Orders in Brazilian Reals Per Month'}, xlabel='order_purchase_timestamp'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113193 entries, 0 to 113192
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    113193 non-null  object
#  1   customer_unique_id             113193 non-null  object
#  2   customer_zip_code_prefix       113193 non-null  object
#  3   customer_city                  113193 non-null  object
#  4   customer_state                 113193 non-null  object
#  5   order_id                       113193 non-null  object
#  6   order_status                   113193 non-null  object
#  7   order_purchase_timestamp       113193 non-null  datetime64[ns]
#  8   order_approved_at              113193 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   113193 non-null  datetime64[ns]
#  10  order_delivered_customer_date  113193 non-null  datetime64[ns]
#  11  order_estimated_delivery_date  113193 non-null  datetime64[ns]
#  12  order_item_id                  113193 non-null  int64
#  13  product_id                     113193 non-null  object
#  14  seller_id                      113193 non-null  object
#  15  shipping_limit_date            113193 non-null  datetime64[ns]
#  16  price                          113193 non-null  float64
#  17  freight_value                  113193 non-null  float64
#  18  payment_sequential             113193 non-null  int64
#  19  payment_type                   113193 non-null  object
#  20  payment_installments           113193 non-null  int64
#  21  payment_value                  113193 non-null  float64
#  22  review_id                      113193 non-null  object
#  23  review_score                   113193 non-null  int64
#  24  review_creation_date           113193 non-null  datetime64[ns]
#  25  review_answer_timestamp        113193 non-null  datetime64[ns]
#  26  product_category_name          113193 non-null  object
#  27  product_name_lenght            113193 non-null  float64
#  28  product_description_lenght     113193 non-null  float64
#  29  product_photos_qty             113193 non-null  float64
#  30  product_weight_g               113193 non-null  float64
#  31  product_length_cm              113193 non-null  float64
#  32  product_height_cm              113193 non-null  float64
#  33  product_width_cm               113193 non-null  float64
#  34  product_category_name_english  113193 non-null  object
#  35  seller_zip_code_prefix         113193 non-null  object
#  36  seller_city                    113193 non-null  object
#  37  seller_state                   113193 non-null  object
#  38  delivery_accuracy              113193 non-null  float64
#  39  total_value                    113193 non-null  float64
#  40  geolocation_zip_code_prefix    112896 non-null  float64
#  41  geolocation_lat                112896 non-null  float64
#  42  geolocation_lng                112896 non-null  float64
#  43  geolocation_city               112896 non-null  object
#  44  geolocation_state              112896 non-null  object
# dtypes: datetime64[ns](8), float64(15), int64(4), object(18)
# memory usage: 39.7+ MB

# %%
GT= filtered_orders.plot.scatter('order_purchase_timestamp','order_delivered_customer_date', alpha=0.1)
# Out:
# <img src="data:image/png;base64,..." width="432">
