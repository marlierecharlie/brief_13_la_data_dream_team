# %%
import pandas as pd

# %%
OD = pd.read_csv('olist_orders_dataset.csv')

# %%
OD
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
ODT = OD[['order_status', 'order_purchase_timestamp', 'order_approved_at','order_delivered_carrier_date',
          'order_delivered_customer_date','order_estimated_delivery_date']]

# %%
ODT
# Out:
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
ODI = pd.read_csv('olist_order_items_dataset.csv')
ODI
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
ODTI = ODI.merge(OD, on='order_id',how='inner')
ODTI
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
ODTT = ODTI[['order_status', 'order_purchase_timestamp', 'order_approved_at','order_delivered_carrier_date',
          'order_delivered_customer_date','order_estimated_delivery_date','shipping_limit_date','price','freight_value']]

# %%
ODTT
# Out:
#        order_status order_purchase_timestamp    order_approved_at  \
# 0         delivered      2017-09-13 08:59:02  2017-09-13 09:45:35
# 1         delivered      2017-04-26 10:53:06  2017-04-26 11:05:13
# 2         delivered      2018-01-14 14:33:31  2018-01-14 14:48:30
# 3         delivered      2018-08-08 10:00:35  2018-08-08 10:10:18
# 4         delivered      2017-02-04 13:57:51  2017-02-04 14:10:13
# ...             ...                      ...                  ...
# 112645    delivered      2018-04-23 13:57:06  2018-04-25 04:11:01
# 112646    delivered      2018-07-14 10:26:46  2018-07-17 04:31:48
# 112647    delivered      2017-10-23 17:07:56  2017-10-24 17:14:25
# 112648    delivered      2017-08-14 23:02:59  2017-08-15 00:04:32
# 112649    delivered      2018-06-09 17:00:18  2018-06-09 17:10:13
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-09-19 18:34:16           2017-09-20 23:43:48
# ...

# %%
ODTT.dtypes
# Out:
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# dtype: object

# %%
ODTT['order_approved_at'] = pd.to_datetime(ODTT['order_approved_at'])
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\1913567545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['order_approved_at'] = pd.to_datetime(ODTT['order_approved_at'])

# %%
ODTT.dtypes
# Out:
# order_status                             object
# order_purchase_timestamp                 object
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
ODTT['order_purchase_timestamp'] = pd.to_datetime(ODTT['order_purchase_timestamp'])
ODTT.dtypes
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\2052078230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['order_purchase_timestamp'] = pd.to_datetime(ODTT['order_purchase_timestamp'])
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
ODTT['order_delivered_carrier_date'] = pd.to_datetime(ODTT['order_delivered_carrier_date'])
ODTT.dtypes
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\1655166844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['order_delivered_carrier_date'] = pd.to_datetime(ODTT['order_delivered_carrier_date'])
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
ODTT['order_delivered_customer_date'] = pd.to_datetime(ODTT['order_delivered_customer_date'])
ODTT.dtypes
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\3252743631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['order_delivered_customer_date'] = pd.to_datetime(ODTT['order_delivered_customer_date'])
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date            object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
ODTT['order_estimated_delivery_date'] = pd.to_datetime(ODTT['order_estimated_delivery_date'])
ODTT.dtypes
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\2753720467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['order_estimated_delivery_date'] = pd.to_datetime(ODTT['order_estimated_delivery_date'])
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
ODTT['shipping_limit_date'] = pd.to_datetime(ODTT['shipping_limit_date'])
ODTT.dtypes
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\2392721904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['shipping_limit_date'] = pd.to_datetime(ODTT['shipping_limit_date'])
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# shipping_limit_date              datetime64[ns]
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
ODTT['Date_Arrived'] = ODTT['order_delivered_customer_date'] - ODTT['order_approved_at']
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\1874655681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['Date_Arrived'] = ODTT['order_delivered_customer_date'] - ODTT['order_approved_at']

# %%
ODTT
# Out:
#        order_status order_purchase_timestamp   order_approved_at  \
# 0         delivered      2017-09-13 08:59:02 2017-09-13 09:45:35
# 1         delivered      2017-04-26 10:53:06 2017-04-26 11:05:13
# 2         delivered      2018-01-14 14:33:31 2018-01-14 14:48:30
# 3         delivered      2018-08-08 10:00:35 2018-08-08 10:10:18
# 4         delivered      2017-02-04 13:57:51 2017-02-04 14:10:13
# ...             ...                      ...                 ...
# 112645    delivered      2018-04-23 13:57:06 2018-04-25 04:11:01
# 112646    delivered      2018-07-14 10:26:46 2018-07-17 04:31:48
# 112647    delivered      2017-10-23 17:07:56 2017-10-24 17:14:25
# 112648    delivered      2017-08-14 23:02:59 2017-08-15 00:04:32
# 112649    delivered      2018-06-09 17:00:18 2018-06-09 17:10:13
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-09-19 18:34:16           2017-09-20 23:43:48
# ...

# %%
ODTT['Date_Estimated'] = ODTT['order_estimated_delivery_date'] - ODTT['order_approved_at']
ODTT
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4512\1323514052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ODTT['Date_Estimated'] = ODTT['order_estimated_delivery_date'] - ODTT['order_approved_at']
#        order_status order_purchase_timestamp   order_approved_at  \
# 0         delivered      2017-09-13 08:59:02 2017-09-13 09:45:35
# 1         delivered      2017-04-26 10:53:06 2017-04-26 11:05:13
# 2         delivered      2018-01-14 14:33:31 2018-01-14 14:48:30
# 3         delivered      2018-08-08 10:00:35 2018-08-08 10:10:18
# 4         delivered      2017-02-04 13:57:51 2017-02-04 14:10:13
# ...             ...                      ...                 ...
# ...

# %%
OG = pd.read_csv('olist_geolocation_dataset.csv')
OG
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
OC = pd.read_csv('olist_customers_dataset.csv')
OC
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
OCDT = ODTT.merge(OC, on='customer_id')
