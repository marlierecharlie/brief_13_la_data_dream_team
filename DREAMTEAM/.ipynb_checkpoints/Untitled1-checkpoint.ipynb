# %%
import pandas as pd

# %%
OD = pd.read_csv('olist_orders_dataset.csv')
ODI = pd.read_csv('olist_order_items_dataset.csv')
OG = pd.read_csv('olist_geolocation_dataset.csv')
OC = pd.read_csv('olist_customers_dataset.csv')

# %%
OC
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
OD
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
ODI
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
OG
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
O = OC[['customer_id','customer_zip_code_prefix','customer_city','customer_state']]

# %%
O
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1      18955e83d337fd6b2def6b18a428ac77                      9790
# 2      4e7b3e00288586ebd08712fdd0374a03                      1151
# 3      b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4      4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                 ...                       ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 99437  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 99438  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 99439  56b18e2166679b8a959d72dd06da27f9                     92120
# 99440  274fa6071e5e17fe303b9748641082c8                      6703
#
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# ...

# %%
O = O.merge(OD, on='customer_id',how='inner')

# %%
O
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1      18955e83d337fd6b2def6b18a428ac77                      9790
# 2      4e7b3e00288586ebd08712fdd0374a03                      1151
# 3      b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4      4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                 ...                       ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 99437  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 99438  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 99439  56b18e2166679b8a959d72dd06da27f9                     92120
# 99440  274fa6071e5e17fe303b9748641082c8                      6703
#
#                customer_city customer_state                          order_id  \
# 0                     franca             SP  00e7ee1b050b8499577073aeb2a297a1
# ...

# %%
O = O.merge(ODI, on='order_id',how='inner')

# %%
O.dropna()
# Out:
#                              customer_id  customer_zip_code_prefix  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1       18955e83d337fd6b2def6b18a428ac77                      9790
# 2       4e7b3e00288586ebd08712fdd0374a03                      1151
# 3       b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4       4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                  ...                       ...
# 112645  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 112646  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 112647  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 112648  56b18e2166679b8a959d72dd06da27f9                     92120
# 112649  274fa6071e5e17fe303b9748641082c8                      6703
#
#                 customer_city customer_state  \
# 0                      franca             SP
# 1       sao bernardo do campo             SP
# ...

# %%
O
# Out:
#                              customer_id  customer_zip_code_prefix  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1       18955e83d337fd6b2def6b18a428ac77                      9790
# 2       4e7b3e00288586ebd08712fdd0374a03                      1151
# 3       b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4       4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                  ...                       ...
# 112645  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 112646  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 112647  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 112648  56b18e2166679b8a959d72dd06da27f9                     92120
# 112649  274fa6071e5e17fe303b9748641082c8                      6703
#
#                 customer_city customer_state  \
# 0                      franca             SP
# 1       sao bernardo do campo             SP
# ...

# %%
OT = O.merge(OG,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix', how='right')
OT
# Out:
#                                customer_id  customer_zip_code_prefix  \
# 0         05b005e82f3f2dcc41b5504f00484e50                    1037.0
# 1         19ee522d0dd140702062bb89e4820e19                    1037.0
# 2         6519f59a7687a4661f7c8a7e24f28f94                    1037.0
# 3         6519f59a7687a4661f7c8a7e24f28f94                    1037.0
# 4         9a02295e3381803554347ab4dc1ab41b                    1046.0
# ...                                    ...                       ...
# 17227979  11ec73ddb032be97ae8f0219cce6cfa3                   99950.0
# 17227980  51293a462a75bbaa62b024a7da9e068a                   99950.0
# 17227981  4e37f00d687d9dbb17009dea9767b1e6                   99950.0
# 17227982  cbc69ea8e3b1fdb3cbc421f7d3f72fc1                   99950.0
# 17227983  f8260ac0cb6df254a4c7ec7dd62a3aaa                   99950.0
#
#          customer_city customer_state                          order_id  \
# ...

# %%
OT.drop_duplicates()
# Out:
#                                customer_id  customer_zip_code_prefix  \
# 0         05b005e82f3f2dcc41b5504f00484e50                    1037.0
# 1         19ee522d0dd140702062bb89e4820e19                    1037.0
# 2         6519f59a7687a4661f7c8a7e24f28f94                    1037.0
# 3         6519f59a7687a4661f7c8a7e24f28f94                    1037.0
# 4         9a02295e3381803554347ab4dc1ab41b                    1046.0
# ...                                    ...                       ...
# 17227953  cbc69ea8e3b1fdb3cbc421f7d3f72fc1                   99950.0
# 17227954  f8260ac0cb6df254a4c7ec7dd62a3aaa                   99950.0
# 17227972  964b34423c822e9bd9831635ccc83db2                   99980.0
# 17227973  964b34423c822e9bd9831635ccc83db2                   99980.0
# 17227974  657ba09c6edfbbc09f6054f541ec1f90                   99980.0
#
#             customer_city customer_state                          order_id  \
# ...

# %%
OT.dropna()
# Out:
#                                customer_id  customer_zip_code_prefix  \
# 0         05b005e82f3f2dcc41b5504f00484e50                    1037.0
# 1         19ee522d0dd140702062bb89e4820e19                    1037.0
# 2         6519f59a7687a4661f7c8a7e24f28f94                    1037.0
# 3         6519f59a7687a4661f7c8a7e24f28f94                    1037.0
# 4         9a02295e3381803554347ab4dc1ab41b                    1046.0
# ...                                    ...                       ...
# 17227979  11ec73ddb032be97ae8f0219cce6cfa3                   99950.0
# 17227980  51293a462a75bbaa62b024a7da9e068a                   99950.0
# 17227981  4e37f00d687d9dbb17009dea9767b1e6                   99950.0
# 17227982  cbc69ea8e3b1fdb3cbc421f7d3f72fc1                   99950.0
# 17227983  f8260ac0cb6df254a4c7ec7dd62a3aaa                   99950.0
#
#          customer_city customer_state                          order_id  \
# ...

# %%
O
# Out:
#                              customer_id  customer_zip_code_prefix  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1       18955e83d337fd6b2def6b18a428ac77                      9790
# 2       4e7b3e00288586ebd08712fdd0374a03                      1151
# 3       b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4       4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                  ...                       ...
# 112645  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 112646  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 112647  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 112648  56b18e2166679b8a959d72dd06da27f9                     92120
# 112649  274fa6071e5e17fe303b9748641082c8                      6703
#
#                 customer_city customer_state  \
# 0                      franca             SP
# 1       sao bernardo do campo             SP
# ...

# %%
O.dtypes
# Out:
# customer_id                              object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# order_id                                 object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# order_item_id                             int64
# product_id                               object
# seller_id                                object
# shipping_limit_date                      object
# price                                   float64
# freight_value                           float64
# dtype: object

# %%
O['order_approved_at'] = pd.to_datetime(O['order_approved_at'])

# %%
O['order_purchase_timestamp'] = pd.to_datetime(O['order_purchase_timestamp'])

# %%
O['order_delivered_carrier_date'] = pd.to_datetime(O['order_delivered_carrier_date'])

# %%
O['order_delivered_customer_date'] = pd.to_datetime(O['order_delivered_customer_date'])

# %%
O['order_estimated_delivery_date'] = pd.to_datetime(O['order_estimated_delivery_date'])

# %%
O['shipping_limit_date'] = pd.to_datetime(O['shipping_limit_date'])

# %%
O['Date_Arrived'] = O['order_delivered_customer_date'] - O['order_approved_at']

# %%
O['Date_Estimated'] = O['order_estimated_delivery_date'] - O['order_approved_at']

# %%
O
# Out:
#                              customer_id  customer_zip_code_prefix  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1       18955e83d337fd6b2def6b18a428ac77                      9790
# 2       4e7b3e00288586ebd08712fdd0374a03                      1151
# 3       b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4       4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                  ...                       ...
# 112645  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 112646  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 112647  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 112648  56b18e2166679b8a959d72dd06da27f9                     92120
# 112649  274fa6071e5e17fe303b9748641082c8                      6703
#
#                 customer_city customer_state  \
# 0                      franca             SP
# 1       sao bernardo do campo             SP
# ...
